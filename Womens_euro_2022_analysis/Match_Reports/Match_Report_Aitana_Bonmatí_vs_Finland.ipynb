# %%
# %matplotlib inline

from statsbombpy import sb

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import font_manager as fm, rcParams
import os
from mplsoccer.pitch import Pitch

from mplsoccer import Pitch, VerticalPitch, FontManager, Sbopen
from mplsoccer.utils import FontManager
import seaborn as sns
from matplotlib.colors import to_rgba, LinearSegmentedColormap
import matplotlib.gridspec as gridspec
import matplotlib.patheffects as path_effects

from PIL import Image

from urllib.request import urlopen, urlretrieve
from highlight_text import HighlightText, ax_text, fig_text
import requests
from io import BytesIO
import cmasher as cmr

# %%
sb.matches(competition_id=53, season_id=106)
# Out:
#     match_id  match_date      kick_off                 competition season  \
# 0    3847567  2022-07-31  18:00:00.000  Europe - UEFA Women's Euro   2022
# 1    3845506  2022-07-26  21:00:00.000  Europe - UEFA Women's Euro   2022
# 2    3835335  2022-07-15  21:00:00.000  Europe - UEFA Women's Euro   2022
# 3    3835323  2022-07-09  18:00:00.000  Europe - UEFA Women's Euro   2022
# 4    3835325  2022-07-10  21:00:00.000  Europe - UEFA Women's Euro   2022
# 5    3835324  2022-07-09  21:00:00.000  Europe - UEFA Women's Euro   2022
# 6    3835331  2022-07-13  18:00:00.000  Europe - UEFA Women's Euro   2022
# 7    3835320  2022-07-07  21:00:00.000  Europe - UEFA Women's Euro   2022
# 8    3845507  2022-07-27  21:00:00.000  Europe - UEFA Women's Euro   2022
# 9    3844387  2022-07-23  21:00:00.000  Europe - UEFA Women's Euro   2022
# 10   3844384  2022-07-20  21:00:00.000  Europe - UEFA Women's Euro   2022
# 11   3844385  2022-07-21  21:00:00.000  Europe - UEFA Women's Euro   2022
# 12   3844386  2022-07-22  21:00:00.000  Europe - UEFA Women's Euro   2022
# 13   3835342  2022-07-18  21:00:00.000  Europe - UEFA Women's Euro   2022
# 14   3835337  2022-07-16  21:00:00.000  Europe - UEFA Women's Euro   2022
# 15   3835338  2022-07-16  21:00:00.000  Europe - UEFA Women's Euro   2022
# 16   3835330  2022-07-12  21:00:00.000  Europe - UEFA Women's Euro   2022
# 17   3835329  2022-07-12  18:00:00.000  Europe - UEFA Women's Euro   2022
# 18   3835322  2022-07-08  21:00:00.000  Europe - UEFA Women's Euro   2022
# 19   3835332  2022-07-13  21:00:00.000  Europe - UEFA Women's Euro   2022
# 20   3835327  2022-07-11  21:00:00.000  Europe - UEFA Women's Euro   2022
# 21   3835326  2022-07-10  18:00:00.000  Europe - UEFA Women's Euro   2022
# 22   3835341  2022-07-18  21:00:00.000  Europe - UEFA Women's Euro   2022
# 23   3835340  2022-07-17  18:00:00.000  Europe - UEFA Women's Euro   2022
# 24   3835339  2022-07-17  18:00:00.000  Europe - UEFA Women's Euro   2022
# 25   3835336  2022-07-15  21:00:00.000  Europe - UEFA Women's Euro   2022
# 26   3835334  2022-07-14  18:00:00.000  Europe - UEFA Women's Euro   2022
# 27   3835328  2022-07-11  18:00:00.000  Europe - UEFA Women's Euro   2022
# 28   3835333  2022-07-14  21:00:00.000  Europe - UEFA Women's Euro   2022
# 29   3835321  2022-07-08  18:00:00.000  Europe - UEFA Women's Euro   2022
# 30   3835319  2022-07-06  21:00:00.000  Europe - UEFA Women's Euro   2022
#
#               home_team            away_team  home_score  away_score  \
# 0       England Women's      Germany Women's           2           1
# 1       England Women's       Sweden Women's           4           0
# 2      Northern Ireland      England Women's           0           5
# 3      Portugal Women's  Switzerland Women's           2           2
# 4        France Women's        Italy Women's           5           1
# 5   Netherlands Women's       Sweden Women's           1           1
# 6        Sweden Women's  Switzerland Women's           2           1
# 7        Norway Women's     Northern Ireland           4           1
# 8       Germany Women's       France Women's           2           1
# 9        France Women's  Netherlands Women's           1           0
# 10      England Women's        Spain Women's           2           1
# 11      Germany Women's      Austria Women's           2           0
# 12       Sweden Women's      Belgium Women's           1           0
# 13      Iceland Women's       France Women's           1           1
# 14      Denmark Women's        Spain Women's           0           1
# 15          WNT Finland      Germany Women's           0           3
# 16      Germany Women's        Spain Women's           2           0
# 17      Denmark Women's          WNT Finland           1           0
# 18      Germany Women's      Denmark Women's           4           0
# 19  Netherlands Women's     Portugal Women's           3           2
# 20      England Women's       Norway Women's           8           0
# 21      Belgium Women's      Iceland Women's           1           1
# 22        Italy Women's      Belgium Women's           0           1
# 23       Sweden Women's     Portugal Women's           5           0
# 24  Switzerland Women's  Netherlands Women's           1           4
# 25      Austria Women's       Norway Women's           1           0
# 26        Italy Women's      Iceland Women's           1           1
# 27      Austria Women's     Northern Ireland           2           0
# 28       France Women's      Belgium Women's           2           1
# 29        Spain Women's          WNT Finland           4           1
# 30      England Women's      Austria Women's           1           0
#
#    match_status  ...            last_updated_360 match_week competition_stage  \
# 0     available  ...  2022-09-12T15:04:12.439476          6             Final
# 1     available  ...  2022-09-06T06:29:30.151649          5       Semi-finals
# 2     available  ...  2022-08-25T15:50:02.843890          3       Group Stage
# 3     available  ...  2022-08-29T19:19:33.588699          1       Group Stage
# 4     available  ...  2022-09-04T19:01:10.410332          1       Group Stage
# 5     available  ...  2022-08-29T19:17:00.202011          1       Group Stage
# 6     available  ...  2022-08-25T19:03:09.037945          2       Group Stage
# 7     available  ...  2022-08-25T10:44:36.086663          1       Group Stage
# 8     available  ...  2022-08-25T21:30:18.952432          5       Semi-finals
# 9     available  ...  2022-08-29T20:59:06.480438          4    Quarter-finals
# 10    available  ...  2022-08-28T11:04:52.754223          4    Quarter-finals
# 11    available  ...            2022-08-04T12:00          4    Quarter-finals
# 12    available  ...  2022-08-26T00:43:22.824600          4    Quarter-finals
# 13    available  ...  2022-09-13T17:04:11.418708          3       Group Stage
# 14    available  ...            2022-08-04T12:00          3       Group Stage
# 15    available  ...            2022-08-04T12:00          3       Group Stage
# 16    available  ...  2022-09-12T15:42:06.543941          2       Group Stage
# 17    available  ...  2022-09-10T18:58:48.011547          2       Group Stage
# 18    available  ...  2022-09-01T12:39:23.294457          1       Group Stage
# 19    available  ...  2022-08-25T18:55:03.279402          2       Group Stage
# 20    available  ...  2022-08-29T19:25:39.212245          2       Group Stage
# 21    available  ...            2022-08-04T12:00          1       Group Stage
# 22    available  ...  2022-08-29T20:12:23.147005          3       Group Stage
# 23    available  ...  2022-09-12T20:13:01.116511          3       Group Stage
# 24    available  ...  2022-09-01T22:46:08.584680          3       Group Stage
# 25    available  ...  2022-08-30T20:01:37.738794          3       Group Stage
# 26    available  ...  2022-08-27T17:17:09.967851          2       Group Stage
# 27    available  ...            2022-08-04T12:00          2       Group Stage
# 28    available  ...  2022-08-29T19:53:47.480272          2       Group Stage
# 29    available  ...  2022-09-06T18:07:06.110124          1       Group Stage
# 30    available  ...  2022-09-06T17:38:20.617412          1       Group Stage
#
#                                    stadium                   referee  \
# 0                          Wembley Stadium           Kateryna Monzul
# 1                             Bramall Lane            Esther Staubli
# 2                      St. Mary''s Stadium            Esther Staubli
# 3             Leigh Sports Village Stadium             Jana Adamkova
# 4                AESSEAL New York Stadium              Rebecca Welch
# 5                             Bramall Lane             Cheryl Foster
# 6                             Bramall Lane       Marta Huerta de Aza
# 7                      St. Mary''s Stadium           Lina Lehtovaara
# 8                               Stadium MK             Cheryl Foster
# 9                AESSEAL New York Stadium            Ivana Martinčić
# 10  The American Express Community Stadium        Stéphanie Frappart
# 11             Brentford Community Stadium             Rebecca Welch
# 12            Leigh Sports Village Stadium           Kateryna Monzul
# 13               AESSEAL New York Stadium              Jana Adamkova
# 14             Brentford Community Stadium             Rebecca Welch
# 15                              Stadium MK    Emikar Caldera Barrera
# 16             Brentford Community Stadium        Stéphanie Frappart
# 17                              Stadium MK  Iuliana Elena Demetrescu
# 18             Brentford Community Stadium            Esther Staubli
# 19            Leigh Sports Village Stadium           Ivana Martinčić
# 20  The American Express Community Stadium              Riem Hussein
# 21                        Academy Stadium              Tess Olofsson
# 22                        Academy Stadium            Ivana Martinčić
# 23            Leigh Sports Village Stadium        Stéphanie Frappart
# 24                            Bramall Lane  Iuliana Elena Demetrescu
# 25  The American Express Community Stadium           Kateryna Monzul
# 26                        Academy Stadium            Lina Lehtovaara
# 27                     St. Mary''s Stadium    Emikar Caldera Barrera
# 28               AESSEAL New York Stadium              Cheryl Foster
# 29                              Stadium MK           Kateryna Monzul
# 30                            Old Trafford       Marta Huerta de Aza
#
#                             home_managers  \
# 0                Sarina Glotzbach-Wiegman
# 1                Sarina Glotzbach-Wiegman
# 2                            Kenny Shiels
# 3   Francisco Miguel Conceição Roque Neto
# 4                Corinne Catherine Diacre
# 5              Mark Richard David Parsons
# 6                       Peter Gerhardsson
# 7                          Martin Sjögren
# 8                Martina Voss-Tecklenburg
# 9                Corinne Catherine Diacre
# 10               Sarina Glotzbach-Wiegman
# 11               Martina Voss-Tecklenburg
# 12                      Peter Gerhardsson
# 13                 Thorsteinn Halldórsson
# 14                       Lars Søndergaard
# 15                           Anna Signeul
# 16               Martina Voss-Tecklenburg
# 17                       Lars Søndergaard
# 18               Martina Voss-Tecklenburg
# 19             Mark Richard David Parsons
# 20               Sarina Glotzbach-Wiegman
# 21                          Ives Serneels
# 22                       Milena Bertolini
# 23                      Peter Gerhardsson
# 24           Nils Herbert Kromann Nielsen
# 25                         Irene Fuhrmann
# 26                       Milena Bertolini
# 27                         Irene Fuhrmann
# 28               Corinne Catherine Diacre
# 29                            Jorge Vilda
# 30               Sarina Glotzbach-Wiegman
#
#                             away_managers data_version shot_fidelity_version  \
# 0                Martina Voss-Tecklenburg        1.1.0                     2
# 1                       Peter Gerhardsson        1.1.0                     2
# 2                Sarina Glotzbach-Wiegman        1.1.0                     2
# 3            Nils Herbert Kromann Nielsen        1.1.0                     2
# 4                        Milena Bertolini        1.1.0                     2
# 5                       Peter Gerhardsson        1.1.0                     2
# 6            Nils Herbert Kromann Nielsen        1.1.0                     2
# 7                            Kenny Shiels        1.1.0                     2
# 8                Corinne Catherine Diacre        1.1.0                     2
# 9              Mark Richard David Parsons        1.1.0                     2
# 10                            Jorge Vilda        1.1.0                     2
# 11                         Irene Fuhrmann        1.1.0                     2
# 12                          Ives Serneels        1.1.0                     2
# 13               Corinne Catherine Diacre        1.1.0                     2
# 14                            Jorge Vilda        1.1.0                     2
# 15               Martina Voss-Tecklenburg        1.1.0                     2
# 16                            Jorge Vilda        1.1.0                     2
# 17                           Anna Signeul        1.1.0                     2
# 18                       Lars Søndergaard        1.1.0                     2
# 19  Francisco Miguel Conceição Roque Neto        1.1.0                     2
# 20                         Martin Sjögren        1.1.0                     2
# 21                 Thorsteinn Halldórsson        1.1.0                     2
# 22                          Ives Serneels        1.1.0                     2
# 23  Francisco Miguel Conceição Roque Neto        1.1.0                     2
# 24             Mark Richard David Parsons        1.1.0                     2
# 25                         Martin Sjögren        1.1.0                     2
# 26                 Thorsteinn Halldórsson        1.1.0                     2
# 27                           Kenny Shiels        1.1.0                     2
# 28                          Ives Serneels        1.1.0                     2
# 29                           Anna Signeul        1.1.0                     2
# 30                         Irene Fuhrmann        1.1.0                     2
#
#    xy_fidelity_version
# 0                    2
# 1                    2
# 2                    2
# 3                    2
# 4                    2
# 5                    2
# 6                    2
# 7                    2
# 8                    2
# 9                    2
# 10                   2
# 11                   2
# 12                   2
# 13                   2
# 14                   2
# 15                   2
# 16                   2
# 17                   2
# 18                   2
# 19                   2
# 20                   2
# 21                   2
# 22                   2
# 23                   2
# 24                   2
# 25                   2
# 26                   2
# 27                   2
# 28                   2
# 29                   2
# 30                   2
#
# [31 rows x 22 columns]

# %%
parser = Sbopen()
match_files = [3835321]
df = pd.concat([parser.event(file)[0] for file in match_files])

# %%
sb.lineups(match_id=3835321)
# Out:
# {"Spain Women's":     player_id                       player_name       player_nickname  \
#  0       10142      Sandra Paños García-Villamil          Sandra Paños
#  1       10150             Andrea Pereira Cejudo        Andrea Pereira
#  2       10155          María Pilar León Cebrián             Mapi León
#  3       10161  María Francesca Caldentey Oliver     Mariona Caldentey
#  4       10163          Leila Ouahabi El Ouahabi         Leila Ouahabi
#  5       10165           Irene Paredes Hernandez       Irene Hernandez
#  6       15284              Aitana Bonmati Conca        Aitana Bonmati
#  7       15287       Patricia Guijarro Gutiérrez        Patri Guijarro
#  8       25513              Lucía García Córdoba          Lucía García
#  9       32210             Laia Aleixandri López       Laia Aleixandri
#  10      32838               Claudia Pina Medina          Claudia Pina
#  11      45667      María Dolores Gallardo Nuñez         Lola Gallardo
#  12      46639                Ona Batlle Pascual            Ona Batlle
#  13      49830     María Isabel Rodríguez Rivero        Misa Rodríguez
#  14      49831                 Ivana Andrés Sanz                  None
#  15      49832           Marta Cardona De Miguel         Marta Cardona
#  16      49835           Teresa Abelleira Dueñas      Teresa Abelleira
#  17      49836              Olga  Carmona García          Olga Carmona
#  18      49913      Athenea del Castillo Belvide  Athenea del Castillo
#  19      50146         Esther Gonzalez Rodríguez       Esther Gonzalez
#  20      50150          Irene Guerrero Sanmartín        Irene Guerrero
#  21      50368                   Amaiur Sarriegi                  None
#  22      51062               Sheila García Gómez         Sheila García
#
#      jersey_number country                                              cards  \
#  0              13   Spain                                                 []
#  1              20   Spain                                                 []
#  2              16   Spain                                                 []
#  3               8   Spain                                                 []
#  4              15   Spain                                                 []
#  5               4   Spain  [{'time': '53:37', 'card_type': 'Yellow Card',...
#  6               6   Spain                                                 []
#  7              12   Spain                                                 []
#  8              17   Spain                                                 []
#  9               3   Spain                                                 []
#  10             22   Spain                                                 []
#  11              1   Spain                                                 []
#  12              2   Spain                                                 []
#  13             23   Spain                                                 []
#  14              5   Spain                                                 []
#  15             11   Spain                                                 []
#  16             18   Spain                                                 []
#  17             19   Spain                                                 []
#  18             10   Spain                                                 []
#  19              9   Spain                                                 []
#  20              7   Spain                                                 []
#  21             14   Spain                                                 []
#  22             21   Spain                                                 []
#
#                                              positions
#  0   [{'position_id': 1, 'position': 'Goalkeeper', ...
#  1                                                  []
#  2   [{'position_id': 5, 'position': 'Left Center B...
#  3   [{'position_id': 21, 'position': 'Left Wing', ...
#  4   [{'position_id': 6, 'position': 'Left Back', '...
#  5   [{'position_id': 3, 'position': 'Right Center ...
#  6   [{'position_id': 13, 'position': 'Right Center...
#  7   [{'position_id': 10, 'position': 'Center Defen...
#  8   [{'position_id': 17, 'position': 'Right Wing',...
#  9   [{'position_id': 15, 'position': 'Left Center ...
#  10  [{'position_id': 23, 'position': 'Center Forwa...
#  11                                                 []
#  12  [{'position_id': 2, 'position': 'Right Back', ...
#  13                                                 []
#  14                                                 []
#  15  [{'position_id': 23, 'position': 'Center Forwa...
#  16                                                 []
#  17                                                 []
#  18  [{'position_id': 13, 'position': 'Right Center...
#  19  [{'position_id': 23, 'position': 'Center Forwa...
#  20  [{'position_id': 15, 'position': 'Left Center ...
#  21                                                 []
#  22  [{'position_id': 6, 'position': 'Left Back', '...  ,
#  'WNT Finland':     player_id                    player_name  player_nickname  jersey_number  \
#  0       13709          Tuija Annika Hyyrynen             None              3
#  1       13713                Linda Sällström             None             18
#  2       13857  Tinja-Riikka Tellervo Korpela             None             23
#  3       13860     Anna Åsa Olivia Westerlund  Anna Westerlund             16
#  4       13861                    Nora Heroum             None             11
#  5       13862                    Emmi Alanen             None             10
#  6       13865                 Natalia Kuikka             None             15
#  7       13896                    Essi Sainio             None             19
#  8       16390                Juliette Kemppi             None              9
#  9       17273                 Adelina Engman             None              7
#  10      32232            Sanni Maija Franssi             None             17
#  11      32403       Emma Wilhelmina Koivisto             None              5
#  12      45018            Katriina Talaslahti             None              1
#  13      45728             Anna Emlia Auvinen             None              6
#  14     191850              Eveliina Summanen             None             20
#  15     224822                  Jutta Rantala             None             22
#  16     225160               Jenny Danielsson             None             13
#  17     225161                Elli Pikkujämsä             None              2
#  18     225163                 Heidi Kollanen             None             14
#  19     225181                Amanda Rantanen             None             21
#  20     225383                      Ria Öling             None              4
#  21     228743                  Anna Tamminen             None             12
#  22     229194                   Olga Ahtinen             None              8
#
#      country                                              cards  \
#  0   Finland                                                 []
#  1   Finland                                                 []
#  2   Finland                                                 []
#  3   Finland                                                 []
#  4   Finland                                                 []
#  5   Finland  [{'time': '79:44', 'card_type': 'Yellow Card',...
#  6   Finland                                                 []
#  7   Finland                                                 []
#  8   Finland                                                 []
#  9   Finland                                                 []
#  10  Finland                                                 []
#  11  Finland                                                 []
#  12  Finland                                                 []
#  13  Finland                                                 []
#  14  Finland                                                 []
#  15  Finland                                                 []
#  16  Finland                                                 []
#  17  Finland                                                 []
#  18  Finland                                                 []
#  19  Finland                                                 []
#  20  Finland                                                 []
#  21  Finland                                                 []
#  22  Finland                                                 []
#
#                                              positions
#  0   [{'position_id': 2, 'position': 'Right Back', ...
#  1   [{'position_id': 22, 'position': 'Right Center...
#  2   [{'position_id': 1, 'position': 'Goalkeeper', ...
#  3   [{'position_id': 3, 'position': 'Right Center ...
#  4                                                  []
#  5   [{'position_id': 11, 'position': 'Left Defensi...
#  6   [{'position_id': 2, 'position': 'Right Back', ...
#  7   [{'position_id': 12, 'position': 'Right Midfie...
#  8                                                  []
#  9   [{'position_id': 12, 'position': 'Right Midfie...
#  10  [{'position_id': 24, 'position': 'Left Center ...
#  11  [{'position_id': 6, 'position': 'Left Back', '...
#  12                                                 []
#  13                                                 []
#  14  [{'position_id': 9, 'position': 'Right Defensi...
#  15                                                 []
#  16  [{'position_id': 24, 'position': 'Left Center ...
#  17  [{'position_id': 5, 'position': 'Left Center B...
#  18                                                 []
#  19  [{'position_id': 16, 'position': 'Left Midfiel...
#  20  [{'position_id': 16, 'position': 'Left Midfiel...
#  21                                                 []
#  22  [{'position_id': 9, 'position': 'Right Defensi...  }

# %%
pitchColor = "#7FB069"
figColor = "#7FB069"
linesColor = "black"
hteamColor = "#EF3340"
secondColor = "#FFD100"
ateamColor = "#003581"
MVP_id = 15284
MVPname = "Aitana Bonmati"
tournament = "Women's EURO 2022"
textColor = "black"
hteam = "Spain Women's"
ateam = "WNT Finland"

pitchCmap = LinearSegmentedColormap.from_list("pitch heatmap", ["#7FB069",hteamColor], N=100)

# %%
Statsbomb = Image.open(r"C:\Users\Gusse\OneDrive\Dokumenter\Python\Womens Euro 2022\sb_text_logo.png")

# %%
URL = 'https://raw.githubusercontent.com/google/fonts/main/apache/roboto/Roboto%5Bwdth,wght%5D.ttf'
URL2 = 'https://raw.githubusercontent.com/google/fonts/main/apache/robotoslab/RobotoSlab%5Bwght%5D.ttf'
robotto_regular = FontManager(URL)
robboto_bold = FontManager(URL2)

# %%
shots = df[df.type_name == "Shot"]
shots = shots[shots.team_name == hteam]

shots = shots[['team_name', 'player_name', 'minute', 'second',"x","y", 'shot_statsbomb_xg', 'outcome_name', "type_name", "id"]]


goals = shots[shots.outcome_name == 'Goal']

# %%
passes = df[df.type_name == "Pass"]
passes = passes[passes.team_name == hteam]
passes = passes[(passes["type_name"]!="Kick Off") & (passes["type_name"]!="Goal Kick") 
                    & (passes["type_name"]!="Free Kick") & (passes["type_name"]!="Throw-in") 
                    & (passes["type_name"]!="Corner") & (passes["outcome_name"]!="Incomplete") 
                    & (passes["outcome_name"]!='Pass Offside') & (passes["outcome_name"]!="Out") 
                    & (passes["outcome_name"]!="Unknown")]

passes = passes[['team_name', 'player_name', "player_id", 'minute', 'second', 'x',"y", "type_name", "outcome_name",
                     "end_x","end_y","pass_goal_assist", "type_name"]]
passes = passes.reset_index()

# %%
passes["outcome_name"].unique()
# Out:
# array([nan], dtype=object)

# %%
passes['beginning'] = np.sqrt(np.square(120-passes['x']) + np.square(40 -passes['y']))
passes['end'] = np.sqrt(np.square(120 - passes['end_x']) + np.square(40 - passes['end_y']))

passes['progressive'] = [(passes['end'][x]) / (passes['beginning'][x]) < .75 for x in range(len(passes.beginning))]

# %%
mvpPasses = df[df["player_id"]== MVP_id]
mvpPasses = mvpPasses[mvpPasses["type_name"]== "Pass"]
mvpPasses = mvpPasses[(mvpPasses["type_name"]!="Kick Off") & (mvpPasses["type_name"]!="Goal Kick") 
                    & (mvpPasses["type_name"]!="Free Kick") & (mvpPasses["type_name"]!="Throw-in") 
                    & (mvpPasses["type_name"]!="Corner") & (mvpPasses["outcome_name"]!="Incomplete") 
                    & (mvpPasses["outcome_name"]!="Pass Offisde") & (mvpPasses["outcome_name"]!="Out") 
                    & (mvpPasses["outcome_name"]!="Unknown")]
mvpPasses = mvpPasses[['team_name', 'player_name', "player_id", 'minute', 'second', 'x',"y", "outcome_name",
                     "end_x","end_y", "type_name", "pass_goal_assist"]]
mvpPasses = mvpPasses.reset_index()

mvpPasses['beginning'] = np.sqrt(np.square(120-mvpPasses['x']) + np.square(40 -mvpPasses['y']))
mvpPasses['end'] = np.sqrt(np.square(120 - mvpPasses['end_x']) + np.square(40 - mvpPasses['end_y']))

mvpPasses['progressive'] = [(mvpPasses['end'][x]) / (mvpPasses['beginning'][x]) < .75 for x in range(len(mvpPasses.beginning))]

mvpPropgPasses = mvpPasses[mvpPasses["progressive"]==True]

assist = mvpPasses[mvpPasses["pass_goal_assist"]==True]

countMvpPasses = mvpPasses.shape[0]
countMVPProg = mvpPropgPasses.shape[0]
countMVPAssist = assist.shape[0]

# %%
events = df[df["player_id"]== MVP_id]
events = events[(events["type_name"]!= 'Ball Receipt') & (events["type_name"]!= 'Injury Stoppage') 
                            & (events["type_name"]!= 'Player Off') & (events["type_name"]!= 'Player On') 
                            & (events["type_name"]!= 'Substitution') & (events["type_name"]!= 'Miscontrol')
                      & (events["type_name"]!= 'Shot') & (events["type_name"]!= 'Dispossessed')]
events = events[(events["outcome_name"]!="Incomplete") & (events["outcome_name"]!="Blocked") 
                      & (events["outcome_name"]!="Out") 
                    & (events["outcome_name"]!="Lost Out") & (events["outcome_name"]!="Lost In Play") 
                & (events["outcome_name"]!="Unknown") & (events["outcome_name"]!="Pass Offside")]

events = events[[ 'player_name',"player_id", 'minute', 'second', 'x',"y", "type_name", 
                             "outcome_name"]]



BallRecovery = events[events.type_name == 'Ball Recovery']

Interception = events[events.type_name == 'Interception']


Dribble = events[events.type_name == 'Dribble']
Dribble = Dribble[Dribble.outcome_name == 'Complete']

Tackle = events[events.type_name == "Tackle"]

Clearance = events[events.type_name == "Clearance"]

Block = events[events.type_name == "Block"]

Carry = events[events.type_name == "Carry"]

Pressure = events[events.type_name == "Pressure"]

Duel = events[events.type_name == "Duel"]
Duel = Duel[Duel['outcome_name'].notna()]

countBallRecovery = BallRecovery.shape[0]
countInterception = Interception.shape[0]
countDribble = Dribble.shape[0]
countClearance = Clearance.shape[0]
countBlock = Block.shape[0]
countCarry = Carry.shape[0]
countPressure = Pressure.shape[0]
countDuel = Duel.shape[0]
countClearance = Clearance.shape[0]

# %%
passes["passer"] = passes["player_id"]
passes["recipient"] = passes["player_id"].shift(-1)

# %%
average_locations = passes.groupby("passer").agg({"x":["mean"], "y": ["mean", "count"]})
average_locations.columns = ["x","y", "count", ]
average_locations.sort_values(by="passer", ascending=True)

mvp_location = average_locations[average_locations.index == MVP_id]

# %%
pitch = VerticalPitch(pitch_type='statsbomb',  line_zorder=2, line_color=linesColor, pitch_color=pitchColor)
fig, axs = pitch.grid(ncols=3, axis=False, endnote_height=0.05)
fig.set_facecolor("lightgrey")

axs["title"].text (0.15, 0.01, f"Average Location", color= textColor, va="center", ha="center",
                   fontsize=18, fontproperties=robotto_regular.prop)

axs["title"].text (0.50, 0.01, f"Pass Map", color= textColor, va="center", ha="center",
                   fontsize=18, fontproperties=robotto_regular.prop)

axs["title"].text (0.85, 0.01, f"Defensive Actions", color= textColor, va="center", ha="center",
                   fontsize=18, fontproperties=robotto_regular.prop)


HighlightText(x=.25, y=19,
              s=f'<{hteam}> vs <{ateam}>', fontsize=30,
              highlight_textprops=[{"color": hteamColor},
                                   {"color": ateamColor}])

TITLE_STR1 = f'{MVPname}s Match Report'
title1_text = axs['title'].text(0.5, 0.7, TITLE_STR1, fontsize=28, color="#454545",
                               fontproperties=robotto_regular.prop,
                                ha='center', va='center')


average_location = pitch.scatter(mvp_location.x, mvp_location.y,
                           s=300,
                           marker= "o", color=hteamColor, edgecolors=secondColor, linewidth=2, alpha=1,
                       ax=axs['pitch'][0], zorder=4)

kde = pitch.kdeplot(events.x, events.y, ax=axs['pitch'][0],
                    shade=True, levels=100,
                    shade_lowest=False,
                    cut=4.1, thresh = .3,
                    cmap = pitchCmap)


pitch.arrows(mvpPasses.x, mvpPasses.y,
             mvpPasses.end_x, mvpPasses.end_y, width=2,
             headwidth=10, headlength=10, color=hteamColor, ax=axs['pitch'][1], alpha = 1, 
             zorder= 2, label=f"Completed passes: {countMvpPasses}")

pitch.arrows(mvpPropgPasses.x, mvpPropgPasses.y,
             mvpPropgPasses.end_x, mvpPropgPasses.end_y, width=2,
             headwidth=10, headlength=10, color="purple", ax=axs['pitch'][1], alpha = 1, 
             zorder=2, label=f"Progressive Passes: {countMVPProg}")

pitch.arrows(assist.x, assist.y,
             assist.end_x, assist.end_y, width=2,
             headwidth=10, headlength=10, color="gold", ax=axs['pitch'][1], alpha = 1, 
             zorder=2, label=f"Assists: {countMVPAssist}")


scatter_recovery = pitch.scatter(BallRecovery.x, BallRecovery.y, c= hteamColor, edgecolor = secondColor,
                                 s=120, marker='s',  ax=axs['pitch'][2], zorder=2, 
                                 label=f"Ball Recoveries: {countBallRecovery}")

scatter_interception = pitch.scatter(Interception.x, Interception.y, c= hteamColor,
                                     s=200, marker='d', edgecolor = secondColor, ax=axs['pitch'][2], zorder=2, 
                                     label=f"Interceptions: {countInterception}")


scatter_duel = pitch.scatter(Duel.x, Duel.y, c=hteamColor, edgecolor= secondColor,
                               s=520, marker=".",  ax=axs['pitch'][2], zorder=2, 
                             label= f"Duels Won: {countDuel}")

scatter_Clearance = pitch.scatter(Clearance.x, Clearance.y, c=hteamColor, edgecolor= secondColor,
                               s=200, marker="^",  ax=axs['pitch'][2], zorder=2, 
                             label= f"Clearances: {countClearance}")

scatter_Block = pitch.scatter(Block.x, Block.y, c=hteamColor, edgecolor= secondColor,
                               s=200, marker="h",  ax=axs['pitch'][2], zorder=2, 
                             label= f"Blocks: {countBlock}")




legend = axs['pitch'][1].legend(loc='upper center', facecolor="none", edgecolor="none", labelspacing=1,  bbox_to_anchor=(0.5, -0.01), fancybox=True)
for text in legend.get_texts():
    text.set_fontsize(15)
    text.set_va('center')
    
legend = axs['pitch'][2].legend(loc='upper center', facecolor="none", edgecolor="none", labelspacing=1,  bbox_to_anchor=(0.5, -0.01))
for text in legend.get_texts():
    text.set_fontsize(15)
    text.set_va('center')

sb_logo = fig.add_axes([0.38, 1.04, 0.25, 0.04])
sb_logo.axis('off')
sb_logo.imshow(Statsbomb)


#plt.savefig(f'viz/{MVPname} Match Report vs {ateam}, {tournament}', dpi=300, bbox_inches='tight')

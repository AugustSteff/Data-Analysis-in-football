# %%
import ScraperFC as sfc
import traceback

# %%
scraper = sfc.FBRef()
try:
    out = scraper.scrape_league_table(2023, 'EPL')
except:
    traceback.print_exc()
scraper.close()
out
# Out:
# Scraping 2023 EPL league table
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1          Arsenal  34  24   6   4  81  39  42   78    2.29  66.6  37.9
# 1    2  Manchester City  32  24   4   4  84  30  54   76    2.38  68.5  25.2
# 2    3    Newcastle Utd  33  18  11   4  61  27  34   65    1.97  60.9  33.4
# 3    4   Manchester Utd  32  19   6   7  49  39  10   63    1.97  52.5  41.7
# 4    5        Liverpool  33  16   8   9  65  42  23   56    1.70  61.6  46.2
# 5    6        Tottenham  34  16   6  12  63  57   6   54    1.59  50.9  45.4
# 6    7      Aston Villa  34  16   6  12  46  42   4   54    1.59  43.4  48.2
# 7    8         Brighton  31  15   7   9  61  40  21   52    1.68  59.5  36.7
# 8    9        Brentford  34  12  14   8  52  44   8   50    1.47  50.6  44.1
# 9   10           Fulham  33  13   6  14  45  45   0   45    1.36  38.9  54.3
# 10  11   Crystal Palace  34  10  10  14  35  45 -10   40    1.18  34.4  44.7
# ...

# %%
scraper = sfc.FBRef()
try:
    # Scrape the match using the FBRef match link
    link = 'https://fbref.com/en/matches/95d2cc61/Leicester-City-Everton-May-1-2023-Premier-League'
    match = scraper.scrape_match(link=link)
except:
    # Catch and print any exceptions.
    traceback.print_exc()
finally:
    # Again, make sure to close the scraper when you're done
    scraper.close()

# %%
complete_report_from_player_link(player_link)

# %%
match['Home Player Stats'].values[0]['Summary']
# Out:
# 0               Unnamed: 0_level_0 Unnamed: 1_level...
# Name: Summary, dtype: object

# %%
scraper = sfc.FBRef()
try:
    out = scraper.scrape_adv_gk(2023, 'EPL', normalize=True, player=True)
except:
    traceback.print_exc()
scraper.close()
out
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Gusse\AppData\Local\Temp\ipykernel_15576\2426378511.py", line 3, in <cell line: 2>
#     out = scraper.scrape_adv_gk(2023, 'EPL', normalize=True, player=True)
# AttributeError: 'FBRef' object has no attribute 'scrape_adv_gk'
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1          Arsenal  34  24   6   4  81  39  42   78    2.29  66.6  37.9
# 1    2  Manchester City  32  24   4   4  84  30  54   76    2.38  68.5  25.2
# 2    3    Newcastle Utd  33  18  11   4  61  27  34   65    1.97  60.9  33.4
# 3    4   Manchester Utd  32  19   6   7  49  39  10   63    1.97  52.5  41.7
# 4    5        Liverpool  33  16   8   9  65  42  23   56    1.70  61.6  46.2
# 5    6        Tottenham  34  16   6  12  63  57   6   54    1.59  50.9  45.4
# 6    7      Aston Villa  34  16   6  12  46  42   4   54    1.59  43.4  48.2
# 7    8         Brighton  31  15   7   9  61  40  21   52    1.68  59.5  36.7
# ...
